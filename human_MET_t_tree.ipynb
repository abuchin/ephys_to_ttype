# %%
# import the libraries

import json
import numpy as np
import matplotlib.pyplot as plt

# %%
# import the tree from json

with open('human_patchseq_dend.json') as f:
    tree = json.load(f)

# show the file
tree
# Out:
# {u'children': [{u'children': [{u'children': [{u'children': [{u'children': [{u'leaf_attributes': [{u'_row': u'Inh L1-2 PAX6 CDH12',
#              u'height': 0,
#              u'label': u'Inh L1-2 PAX6 CDH12',
#              u'leaf': True,
#              u'members': 1,
#              u'nodePar.cex': 2,
#              u'nodePar.col': 3,
#              u'nodePar.lab.col': u'#DDACC9',
#              u'nodePar.pch': 19}]},
#           {u'leaf_attributes': [{u'_row': u'Inh L1-2 PAX6 TNFAIP8L3',
#              u'height': 0,
#              u'label': u'Inh L1-2 PAX6 TNFAIP8L3',
#              u'leaf': True,
#              u'members': 1,
#              u'nodePar.cex': 2,
#              u'nodePar.col': 3,
#              u'nodePar.lab.col': u'#FF88AD',
#              u'nodePar.pch': 19}]}],
#          u'node_attributes': [{u'_row': u'n49',
#            u'height': 0.1516,
#            u'label': u'PAX6',
#            u'members': 2,
#            u'midpoint': 0.5,
#            u'nodePar.cex': 2,
# ...

# %%
tree['children'][0]
# Out:
# {u'children': [{u'children': [{u'children': [{u'children': [{u'leaf_attributes': [{u'_row': u'Inh L1-2 PAX6 CDH12',
#            u'height': 0,
#            u'label': u'Inh L1-2 PAX6 CDH12',
#            u'leaf': True,
#            u'members': 1,
#            u'nodePar.cex': 2,
#            u'nodePar.col': 3,
#            u'nodePar.lab.col': u'#DDACC9',
#            u'nodePar.pch': 19}]},
#         {u'leaf_attributes': [{u'_row': u'Inh L1-2 PAX6 TNFAIP8L3',
#            u'height': 0,
#            u'label': u'Inh L1-2 PAX6 TNFAIP8L3',
#            u'leaf': True,
#            u'members': 1,
#            u'nodePar.cex': 2,
#            u'nodePar.col': 3,
#            u'nodePar.lab.col': u'#FF88AD',
#            u'nodePar.pch': 19}]}],
#        u'node_attributes': [{u'_row': u'n49',
#          u'height': 0.1516,
#          u'label': u'PAX6',
#          u'members': 2,
#          u'midpoint': 0.5,
#          u'nodePar.cex': 2,
#          u'nodePar.col': 3}]},
# ...
